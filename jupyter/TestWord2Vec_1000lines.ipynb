# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/training_code
# Out:
# /content/gdrive/My Drive/training_code

# %%
! git clone https://github.com/vanvibig/RL-Hands-On-Chatbot.git RL-Hands-On-Chatbot-gensim
# Out:
# Cloning into 'RL-Hands-On-Chatbot-gensim'...
# remote: Enumerating objects: 263, done.
# remote: Counting objects: 100% (263/263), done.
# remote: Compressing objects: 100% (167/167), done.
# remote: Total 263 (delta 108), reused 217 (delta 64), pack-reused 0
# Receiving objects: 100% (263/263), 20.99 MiB | 13.92 MiB/s, done.
# Resolving deltas: 100% (108/108), done.

# %%
cd RL-Hands-On-Chatbot-gensim/
# Out:
# /content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim

# %%
! pip install -r requirements.txt

# %%
# !git reset --hard HEAD
# Out:
# HEAD is now at fcae04d re

# %%
! rm -rf saves/ runs/

# %%
! git pull
# Out:
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 10 (delta 5), reused 9 (delta 4), pack-reused 0
# Unpacking objects: 100% (10/10), done.
# From https://github.com/vanvibig/RL-Hands-On-Chatbot
#    ffd8840..9907484  word2vec   -> origin/word2vec
# Updating ffd8840..9907484
# Fast-forward
#  data/cornell/movie_conversations.txt |  9870 +++++++++++++++++
#  data/cornell/movie_lines.txt         | 19740 +++++++++++++++++++++++++++++++++
#  2 files changed, 29610 insertions(+)

# %%
! git fetch && git checkout word2vec
# Out:
# M	libbots/__pycache__/__init__.cpython-36.pyc
# M	libbots/__pycache__/cornell.cpython-36.pyc
# M	libbots/__pycache__/data.cpython-36.pyc
# M	libbots/__pycache__/model.cpython-36.pyc
# M	libbots/__pycache__/utils.cpython-36.pyc
# M	word2vec.txt
# M	word2vec2.txt
# Already on 'word2vec'
# Your branch is up to date with 'origin/word2vec'.

# %%
# !git reset --hard HEAD
# Out:
# HEAD is now at 44a11b5 re edit data

# %%
# !python train_crossent.py --data '' -n crossent
# Out:
# 2019-03-26 12:48:58,843 INFO Read and tokenise phrases...
# 2019-03-26 12:48:59,483 INFO Loaded 20740 phrases
# 2019-03-26 12:48:59,532 INFO Loaded 10370 dialogues with 20740 phrases, generating training pairs
# 2019-03-26 12:48:59,537 INFO Counting freq of words...
# 2019-03-26 12:48:59,616 INFO Data has 5515 uniq words, 3682 of them occur more than 2
# ...

# %%
# !python use_model.py -m '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/saves/crossent/epoch_990_0.971_0.049_0.044.dat'
# Out:
# >>> xin chào
# xin chào
# >>> chào
# cậu nói gì ra rất là nguy_hiểm
# >>> chào cậu
# xin chào
# >>> ăn cơm chưa
# được rồi
# >>> cậu ăn cơm chưa
# sao
# >>> tạm biệt
# xin mời
# >>> cậu có đói không
# không
# >>> cậu có thấy hắn không
# được thôi
# >>> tôi rất yêu_mến cậu
# không sao
# >>> cấc cậu biết đấy ở buổi tiệc
# tiệc nào
# >>> cậu cũng sống ở đây ah
# tôi sống ở căn_hộ gần vỉa_hè
# >>> bữa tiệc thế_nào
# không_thể tệ hơn theo đúng nghĩ đen
# >>> Traceback (most recent call last):
#   File "use_model.py", line 70, in <module>
# KeyboardInterrupt

# %%
! zip -r '/content/gdrive/My Drive/Trained_Data/RL-handon-chatbot-Gensim-seq2seq-1000epoch-1000lines-loss004-testbleu004.zip' '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim'
# Out:
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/update.sample (deflated 68%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/fsmonitor-watchman.sample (deflated 53%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/pre-commit.sample (deflated 43%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/pre-rebase.sample (deflated 59%)
# ...

# %%
! git reset --hard HEAD
# Out:
# HEAD is now at 655eb98 re

# %%
! git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/vanvibig/RL-Hands-On-Chatbot
#    b7c86a3..ffd8840  word2vec   -> origin/word2vec
# Updating b7c86a3..ffd8840
# Fast-forward
#  train_scst.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
! python train_scst.py -l '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/saves/crossent/epoch_990_0.971_0.049_0.044.dat' --data '' --name scst
# Out:
# 2019-03-26 11:52:54,534 INFO Read and tokenise phrases...
# 2019-03-26 11:52:54,569 INFO Loaded 1000 phrases
# 2019-03-26 11:52:54,576 INFO Loaded 500 dialogues with 1000 phrases, generating training pairs
# 2019-03-26 11:52:54,576 INFO Counting freq of words...
# 2019-03-26 11:52:54,581 INFO Data has 779 uniq words, 491 of them occur more than 2
# 2019-03-26 11:52:54,602 WARNING consider setting layer size to a multiple of 4 for greater performance
# 2019-03-26 11:52:54,603 INFO collecting all words and their counts
# 2019-03-26 11:52:54,603 INFO PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-03-26 11:52:54,604 INFO collected 779 word types from a corpus of 4920 raw words and 1000 sentences
# 2019-03-26 11:52:54,604 INFO Loading a fresh vocabulary
# 2019-03-26 11:52:54,606 INFO effective_min_count=2 retains 491 unique words (63% of original 779, drops 288)
# ...

# %%
# !python use_model.py -m '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/saves/scst/epoch_990_0.999_0.050_0.000.dat'
# Out:
# >>> chào
# cậu nói gì ra rất là nguy_hiểm
# >>> xin chào
# cậu khỏe không
# >>> chào cậu
# xin chào
# >>> ăn cơm chưa
# được rồi thôi nhé tôi là elizabeth
# >>> cậu ăn cơm chưa
# sao
# >>> cậu là ai
# tôi là một bí_mật
# >>> cậu tên gì
# elizabeth tôi là dân it
# >>> cậu ở đâu
# tôi là một bí_mật
# >>> quê cậu ở đâu
# số tiền gã áo không hay áo đỏ
# >>> Traceback (most recent call last):
#   File "use_model.py", line 70, in <module>
# KeyboardInterrupt

# %%
! zip -r '/content/gdrive/My Drive/Trained_Data/RL-handon-chatbot-Gensim-RL-1000epoch-1000lines-loss0000000-testbleu005.zip' '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim'
# Out:
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/update.sample (deflated 68%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/fsmonitor-watchman.sample (deflated 53%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/pre-commit.sample (deflated 43%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-gensim/.git/hooks/pre-rebase.sample (deflated 59%)
# ...
