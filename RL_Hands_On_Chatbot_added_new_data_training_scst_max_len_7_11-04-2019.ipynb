# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7
# Out:
# /content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7

# %%
! git clone https://github.com/vanvibig/RL-Hands-On-Chatbot RL-Hands-On-Chatbot-add-new-data-max-len-7
# Out:
# Cloning into 'RL-Hands-On-Chatbot-add-new-data-max-len-7'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 383 (delta 0), reused 1 (delta 0), pack-reused 379
# Receiving objects: 100% (383/383), 21.44 MiB | 7.38 MiB/s, done.
# Resolving deltas: 100% (184/184), done.

# %%
cd RL-Hands-On-Chatbot-add-new-data-max-len-7
# Out:
# /content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7

# %%
! git fetch && git checkout add-new-data-max-len-7
# Out:
# Branch 'add-new-data-max-len-7' set up to track remote branch 'add-new-data-max-len-7' from 'origin'.
# Switched to a new branch 'add-new-data-max-len-7'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#     100% |████████████████████████████████| 13.9MB 3.2MB/s
# ...
#     100% |████████████████████████████████| 519.5MB 29kB/s
# ...
#     100% |████████████████████████████████| 61kB 8.3MB/s
# ...
#     100% |████████████████████████████████| 81kB 27.7MB/s
# ...
#     100% |████████████████████████████████| 83.1MB 438kB/s
# ...
#     100% |████████████████████████████████| 3.1MB 6.7MB/s
# ...
#     100% |████████████████████████████████| 11.3MB 2.2MB/s
# ...
#     100% |████████████████████████████████| 419kB 8.6MB/s
# ...
#     100% |████████████████████████████████| 757kB 8.5MB/s
# ...
#     100% |████████████████████████████████| 1.4MB 7.7MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/4b/c8/24/b2343664bcceb7147efeb21c0b23703a05b23fcfeaceaa2a1e
# Successfully built nltk
# featuretools 0.4.1 has requirement pandas>=0.23.0, but you'll have pandas 0.22.0 which is incompatible.
# fastai 1.0.51 has requirement torch>=1.0.0, but you'll have torch 0.4.1 which is incompatible.
# ...

# %% [markdown]
# ### 08:50 AM. 08-04-2019

# %%
! python train_crossent.py -n crossent --cuda --data ''
# Out:
# 2019-04-08 01:50:54,403 INFO Read and tokenise phrases...
# 2019-04-08 01:50:55,241 INFO Loaded 26132 phrases
# 2019-04-08 01:50:55,318 INFO Loaded 13066 dialogues with 26132 phrases, generating training pairs
# 2019-04-08 01:50:55,367 INFO Counting freq of words...
# 2019-04-08 01:50:55,462 INFO Data has 6496 uniq words, 4188 of them occur more than 2
# 2019-04-08 01:50:55,551 INFO Obtained 8496 phrase pairs with 3510 uniq words
# 2019-04-08 01:50:55,617 INFO Training data converted, got 7470 samples
# 2019-04-08 01:50:55,617 INFO Train set has 7096 phrases, test 374
# 2019-04-08 01:50:58,406 INFO Model: PhraseModel(
#   (emb): Embedding(3510, 50)
#   (encoder): LSTM(50, 512, batch_first=True)
#   (decoder): LSTM(50, 512, batch_first=True)
#   (output): Sequential(
#     (0): Linear(in_features=512, out_features=3510, bias=True)
#   )
# )
# 2019-04-08 01:52:02,347 INFO Epoch 0: mean loss 5.365, mean BLEU 0.103, test BLEU 0.074
# ...

# %%
# !python use_model.py -m '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/saves/crossent/epoch_090_0.917_0.070_loss0.286.dat'
# Out:
# >>> chào
# đừng lo lính mới
# >>> xin chào
# cô khỏe chứ
# >>> chào cậu
# hôm_nay vui chứ
# >>> chào cậu nhé
# tốt còn cậu
# >>> tạm biệt
# tạm_biệt hẹn gặp lại
# >>> Traceback (most recent call last):
#   File "use_model.py", line 72, in <module>
#     input_string = input(">>> ")
# KeyboardInterrupt
# ^C

# %% [markdown]
# #### 01:26 PM, 08-04-2019

# %%
! pip install -r requirements.txt
# Out:
# ...
#     100% |████████████████████████████████| 13.9MB 3.2MB/s
# ...
#     100% |████████████████████████████████| 519.5MB 32kB/s
# ...
#     100% |████████████████████████████████| 61kB 22.0MB/s
# ...
#     100% |████████████████████████████████| 81kB 26.7MB/s
# ...
#     100% |████████████████████████████████| 83.1MB 548kB/s
# ...
#     100% |████████████████████████████████| 3.1MB 7.1MB/s
# ...
#     100% |████████████████████████████████| 11.3MB 2.6MB/s
# ...
#     100% |████████████████████████████████| 757kB 9.2MB/s
# ...
#     100% |████████████████████████████████| 419kB 9.4MB/s
# ...
#     100% |████████████████████████████████| 1.4MB 8.3MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/4b/c8/24/b2343664bcceb7147efeb21c0b23703a05b23fcfeaceaa2a1e
# Successfully built nltk
# featuretools 0.4.1 has requirement pandas>=0.23.0, but you'll have pandas 0.22.0 which is incompatible.
# fastai 1.0.51 has requirement torch>=1.0.0, but you'll have torch 0.4.1 which is incompatible.
# ...

# %%
! git pull
# Out:
# Already up to date.

# %% [markdown]
# #### 9:24PM, 8-4-2019

# %% [markdown]
# #### 9:06AM, 9-4-2019

# %%
# !python train_scst.py -n scstRL --cuda --data '' -l '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7/saves/scstRL/epoch_810_0.9857893258281963_0.08013086844550309_loss0.0020162836120311005.dat' -se 811
# Out:
# 2019-04-09 02:07:11,609 INFO Read and tokenise phrases...
# 2019-04-09 02:07:13,363 INFO Loaded 26132 phrases
# 2019-04-09 02:07:13,746 INFO Loaded 13066 dialogues with 26132 phrases, generating training pairs
# 2019-04-09 02:07:13,752 INFO Counting freq of words...
# 2019-04-09 02:07:13,849 INFO Data has 6496 uniq words, 4188 of them occur more than 2
# 2019-04-09 02:07:13,884 INFO Obtained 8496 phrase pairs with 3510 uniq words
# 2019-04-09 02:07:13,884 INFO Obtained 16992 phrase after max-len clean
# 2019-04-09 02:07:14,203 INFO Training data converted, got 7096 samples
# 2019-04-09 02:07:14,213 INFO Train set has 6462 phrases, test 371
# 2019-04-09 02:07:16,991 INFO Model: PhraseModel(
#   (emb): Embedding(3510, 50)
#   (encoder): LSTM(50, 512, batch_first=True)
#   (decoder): LSTM(50, 512, batch_first=True)
#   (output): Sequential(
#     (0): Linear(in_features=512, out_features=3510, bias=True)
#   )
# )
# ...

# %% [markdown]
# #### 12:42PM, 11-04-2019

# %%
! pip install -r requirements.txt

# %%
# !python use_model.py -m '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7/saves/scstRL/epoch_1360_0.9858995280956614_0.08353457835570298_loss0.001063858576424669.dat' -f 'sadasd'
# Out:
# Bat dau ghi file
# Ket thuc ghi file
# >>> chào
# tokenized: chào
# Bot: cậu là lính mới à
# >>> xin chào
# tokenized: xin chào
# Bot: chào cưng
# >>> chào cậu
# tokenized: chào cậu
# Bot: chào cậu
# >>> chào em
# tokenized: chào em
# Bot: em không ở đâu
# >>> chúc mừng
# tokenized: chúc mừng
# Bot: ừ cô không đâu
# >>> chúc_mừng
# tokenized: chúc_mừng
# Bot: cảm_ơn
# >>> Traceback (most recent call last):
#   File "use_model.py", line 72, in <module>
# KeyboardInterrupt

# %%
# !zip -r '/content/gdrive/My Drive/Trained_Data/RL-Hands-On-Chatbot-add-new-data-max-len-7_epoch1360_loss_0.001_bleu0.08.zip' '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7/'
# Out:
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7/.git/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7/.git/description (deflated 14%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7/.git/branches/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7/.git/info/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7/.git/info/exclude (deflated 28%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7/.git/hooks/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-max-len-7/.git/hooks/update.sample (deflated 68%)
# ...
