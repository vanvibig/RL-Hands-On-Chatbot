# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data'
# Out:
# /content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data

# %%
! git clone https://github.com/vanvibig/RL-Hands-On-Chatbot RL-Hands-On-Chatbot-add-new-data
# Out:
# Cloning into 'RL-Hands-On-Chatbot-add-new-data'...
# remote: Enumerating objects: 379, done.
# remote: Counting objects: 100% (379/379), done.
# remote: Compressing objects: 100% (241/241), done.
# remote: Total 379 (delta 183), reused 298 (delta 103), pack-reused 0
# Receiving objects: 100% (379/379), 21.76 MiB | 14.25 MiB/s, done.
# Resolving deltas: 100% (183/183), done.

# %%
cd RL-Hands-On-Chatbot-add-new-data/
# Out:
# /content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data

# %%
! git fetch && git checkout add-new-data
# Out:
# Branch 'add-new-data' set up to track remote branch 'add-new-data' from 'origin'.
# Switched to a new branch 'add-new-data'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#     100% |████████████████████████████████| 13.9MB 3.1MB/s
# ...
#     100% |████████████████████████████████| 519.5MB 36kB/s
# ...
#     100% |████████████████████████████████| 61kB 23.2MB/s
# ...
#     100% |████████████████████████████████| 81kB 28.2MB/s
# ...
#     100% |████████████████████████████████| 83.1MB 603kB/s
# ...
#     100% |████████████████████████████████| 3.1MB 6.5MB/s
# ...
#     100% |████████████████████████████████| 11.3MB 3.1MB/s
# ...
#     100% |████████████████████████████████| 419kB 8.9MB/s
# ...
#     100% |████████████████████████████████| 1.4MB 7.8MB/s
# ...
#     100% |████████████████████████████████| 757kB 9.0MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/4b/c8/24/b2343664bcceb7147efeb21c0b23703a05b23fcfeaceaa2a1e
# Successfully built nltk
# featuretools 0.4.1 has requirement pandas>=0.23.0, but you'll have pandas 0.22.0 which is incompatible.
# fastai 1.0.51 has requirement torch>=1.0.0, but you'll have torch 0.4.1 which is incompatible.
# ...

# %%
! python train_crossent.py -n crossent --cuda --data ''
# Out:
# 2019-04-04 08:52:22,159 INFO Read and tokenise phrases...
# 2019-04-04 08:52:22,980 INFO Loaded 26132 phrases
# 2019-04-04 08:52:23,056 INFO Loaded 13066 dialogues with 26132 phrases, generating training pairs
# 2019-04-04 08:52:23,105 INFO Counting freq of words...
# 2019-04-04 08:52:23,199 INFO Data has 6496 uniq words, 4188 of them occur more than 2
# 2019-04-04 08:52:23,314 INFO Obtained 13066 phrase pairs with 4191 uniq words
# 2019-04-04 08:52:23,419 INFO Training data converted, got 11173 samples
# 2019-04-04 08:52:23,419 INFO Train set has 10614 phrases, test 559
# 2019-04-04 08:52:26,179 INFO Model: PhraseModel(
#   (emb): Embedding(4191, 50)
#   (encoder): LSTM(50, 512, batch_first=True)
#   (decoder): LSTM(50, 512, batch_first=True)
#   (output): Sequential(
#     (0): Linear(in_features=512, out_features=4191, bias=True)
#   )
# )
# 2019-04-04 08:54:21,778 INFO Epoch 0: mean loss 5.533, mean BLEU 0.091, test BLEU 0.084
# ...

# %%
# !python use_model.py -m '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/saves/crossent/epoch_090_0.917_0.070_loss0.286.dat'
# Out:
# >>> chào
# đừng lo lính mới
# >>> xin chào
# cô khỏe chứ
# >>> chào cậu
# hôm_nay vui chứ
# >>> chào cậu nhé
# tốt còn cậu
# >>> tạm biệt
# tạm_biệt hẹn gặp lại
# >>> Traceback (most recent call last):
#   File "use_model.py", line 72, in <module>
#     input_string = input(">>> ")
# KeyboardInterrupt
# ^C

# %% [markdown]
# #### 08-04-2019, 08:34 AM

# %%
# !python train_scst.py -n scstRL --cuda --data '' -l '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data/saves/crossent/epoch_190_0.930_0.074_loss0.175.dat'
# Out:
# 2019-04-08 01:36:23,258 INFO Read and tokenise phrases...
# 2019-04-08 01:36:25,017 INFO Loaded 26132 phrases
# 2019-04-08 01:36:25,537 INFO Loaded 13066 dialogues with 26132 phrases, generating training pairs
# 2019-04-08 01:36:25,545 INFO Counting freq of words...
# 2019-04-08 01:36:25,642 INFO Data has 6496 uniq words, 4188 of them occur more than 2
# 2019-04-08 01:36:25,691 INFO Obtained 13066 phrase pairs with 4191 uniq words
# 2019-04-08 01:36:25,791 INFO Training data converted, got 10614 samples
# 2019-04-08 01:36:25,805 INFO Train set has 9810 phrases, test 547
# 2019-04-08 01:36:28,575 INFO Model: PhraseModel(
#   (emb): Embedding(4191, 50)
#   (encoder): LSTM(50, 512, batch_first=True)
#   (decoder): LSTM(50, 512, batch_first=True)
#   (output): Sequential(
#     (0): Linear(in_features=512, out_features=4191, bias=True)
#   )
# )
# ...

# %%
# !python use_model.py -m '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/saves/scstRL/epoch_100_0.995_0.069_loss0.022.dat' -f 'sadasd'
# Out:
# Bat dau ghi file
# Ket thuc ghi file
# >>> Traceback (most recent call last):
#   File "use_model.py", line 72, in <module>
# KeyboardInterrupt

# %%
# !zip -r '/content/gdrive/My Drive/Trained_Data/RL-Hands-On-Chatbot-20k_RL_100epoch_loss-0.01_bleu_test-0.07.zip' '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/'
# Out:
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/.git/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/.git/branches/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/.git/info/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/.git/info/exclude (deflated 28%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/.git/description (deflated 14%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/.git/hooks/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/.git/hooks/pre-push.sample (deflated 50%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/.git/hooks/fsmonitor-watchman.sample (deflated 53%)
# ...
