# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd '/content/gdrive/My Drive/training_code/'
# Out:
# /content/gdrive/My Drive/training_code

# %%
cd '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-mini-END'
# Out:
# /content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-mini-END

# %%
! git clone https://github.com/vanvibig/RL-Hands-On-Chatbot RL-Hands-On-Chatbot-add-new-data-mini-END
# Out:
# Cloning into 'RL-Hands-On-Chatbot-add-new-data-mini-END'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 471 (delta 45), reused 62 (delta 21), pack-reused 379
# Receiving objects: 100% (471/471), 22.57 MiB | 19.78 MiB/s, done.
# Resolving deltas: 100% (229/229), done.

# %%
cd RL-Hands-On-Chatbot-add-new-data-mini-END/
# Out:
# /content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data

# %%
! git fetch && git checkout add-new-data-mini-END
# Out:
# Branch 'add-new-data' set up to track remote branch 'add-new-data' from 'origin'.
# Switched to a new branch 'add-new-data'

# %%
pwd
# Out:
# '/content/gdrive/My Drive/training_code'

# %%
cd RL-Hands-On-Chatbot-add-new-data-mini-END/
# Out:
# /content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-mini-END

# %%
# !pip install tensorboard-pytorch==0.7.1 tensorflow==1.12.0 tensorboard==1.12.0
# Out:
# ...
#      |████████████████████████████████| 81kB 3.5MB/s
# ...
#      |████████████████████████████████| 83.1MB 1.5MB/s
# ...
#      |████████████████████████████████| 3.1MB 46.6MB/s
# ...
#   Found existing installation: tensorboard 1.13.1
#     Uninstalling tensorboard-1.13.1:
#       Successfully uninstalled tensorboard-1.13.1
#   Found existing installation: tensorflow 1.13.1
#     Uninstalling tensorflow-1.13.1:
#       Successfully uninstalled tensorflow-1.13.1
# ...

# %%
pwd
# Out:
# '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-mini-END'

# %%
# !git branch -a
# Out:
# * add-new-data-mini-END
#   master
#   remotes/origin/13k
#   remotes/origin/20k
#   remotes/origin/HEAD -> origin/master
#   remotes/origin/add-new-data
#   remotes/origin/add-new-data-END
#   remotes/origin/add-new-data-max-len-7
#   remotes/origin/add-new-data-mini-END
#   remotes/origin/master
#   remotes/origin/word2vec

# %%
# !git fetch && git checkout add-new-data-mini-END
# Out:
# Branch 'add-new-data-mini-END' set up to track remote branch 'add-new-data-mini-END' from 'origin'.
# Switched to a new branch 'add-new-data-mini-END'

# %%
! python train_crossent.py -n crossent --cuda --data ''
# Out:
# 2019-05-07 04:23:48,102 INFO Using device: cuda
# 2019-05-07 04:23:48,105 INFO Read and tokenise phrases...
# 2019-05-07 04:23:48,318 INFO Loaded 8988 phrases
# 2019-05-07 04:23:48,339 INFO Loaded 4494 dialogues with 8988 phrases, generating training pairs
# 2019-05-07 04:23:48,342 INFO Counting freq of words...
# 2019-05-07 04:23:48,368 INFO Data has 3486 uniq words, 1947 of them occur more than 2
# 2019-05-07 04:23:48,407 INFO Obtained 4494 phrase pairs with 1950 uniq words
# 2019-05-07 04:23:48,436 INFO Training data converted, got 3297 samples
# 2019-05-07 04:23:48,436 INFO Train set has 3132 phrases, test 165
# 2019-05-07 04:23:54,688 INFO Model: PhraseModel(
#   (emb): Embedding(1950, 50)
#   (encoder): LSTM(50, 512, batch_first=True)
#   (decoder): LSTM(50, 512, batch_first=True)
#   (output): Sequential(
#     (0): Linear(in_features=512, out_features=1950, bias=True)
#   )
# )
# 2019-05-07 04:24:06,375 INFO Epoch 0: mean loss 5.460, mean BLEU 0.082, test BLEU 0.062
# ...

# %%
# !python use_model.py -m '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-20k/saves/crossent/epoch_090_0.917_0.070_loss0.286.dat'
# Out:
# >>> chào
# đừng lo lính mới
# >>> xin chào
# cô khỏe chứ
# >>> chào cậu
# hôm_nay vui chứ
# >>> chào cậu nhé
# tốt còn cậu
# >>> tạm biệt
# tạm_biệt hẹn gặp lại
# >>> Traceback (most recent call last):
#   File "use_model.py", line 72, in <module>
#     input_string = input(">>> ")
# KeyboardInterrupt
# ^C

# %%
! git pull

# %% [markdown]
# #### 12:38PM, 7-5-2019

# %%
# !wget https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64 -O cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda-9.2
# Out:
# --2019-05-07 06:47:53--  https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.162.216
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.162.216|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/9.2/secure/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb?RYWmRiF_H7tCgOOxnsQDObAKc5vv1fqtYu8yeDD0EZMe74z_s0X8sHgXlcU-7TBK7tpS5JVZhEG8amqyDCz4Ea1Cfyh9b8m3-CEBoqJxnMm-Ci64fXLN2NfCZ8TbMnYEn25Q_tzfumRNBa1Ocyod890nwbhny1OEOgCpQJSTImgYRMG16LAHHwT9gqXhSdkPAQDOqQVjIpP5snMzZfQ [following]
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Wed_Apr_11_23:16:29_CDT_2018
# Cuda compilation tools, release 9.2, V9.2.88

# %%
! pip install ptan==0.3

# %%
# !pip install http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
# Out:
# ...
#      |████████████████████████████████| 512.6MB 1.2MB/s
# ERROR: fastai 1.0.52 has requirement torch>=1.0.0, but you'll have torch 0.4.1 which is incompatible.
# ...
#   Found existing installation: torch 1.1.0
#     Uninstalling torch-1.1.0:
#       Successfully uninstalled torch-1.1.0
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (1/1), done.
# From https://github.com/vanvibig/RL-Hands-On-Chatbot
#    db637f4..b09e740  add-new-data-mini-END -> origin/add-new-data-mini-END
# Updating db637f4..b09e740
# Fast-forward
#  train_scst.py | 3 +--
#  1 file changed, 1 insertion(+), 2 deletions(-)

# %%
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 18.04.2 LTS
# Release:	18.04
# Codename:	bionic

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Tue_Jun_12_23:07:04_CDT_2018
# Cuda compilation tools, release 9.2, V9.2.148

# %%
import torch

print("PyTorch version: ")
print(torch.__version__)
print("CUDA Version: ")
print(torch.version.cuda)
print("cuDNN version is: ")
print(torch.backends.cudnn.version())
# Out:
# PyTorch version:
# 0.4.1
# CUDA Version:
# 9.2.148
# cuDNN version is:
# 7104

# %%
pwd

# %%
# !git branch -a

# %% [markdown]
# ### 2:00PM, 7/5/2019

# %%
# !python train_scst.py -n scstRL --cuda --data '' -l '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data-mini-END/saves/crossent/epoch_190_0.977_0.083_loss0.038.dat'
# Out:
# 2019-05-07 06:53:47,914 INFO Using device: cuda
# 2019-05-07 06:53:47,914 INFO Read and tokenise phrases...
# 2019-05-07 06:53:48,869 INFO Loaded 8988 phrases
# 2019-05-07 06:53:49,190 INFO Loaded 4494 dialogues with 8988 phrases, generating training pairs
# 2019-05-07 06:53:49,193 INFO Counting freq of words...
# 2019-05-07 06:53:49,219 INFO Data has 3486 uniq words, 1947 of them occur more than 2
# 2019-05-07 06:53:49,233 INFO Obtained 4494 phrase pairs with 1950 uniq words
# 2019-05-07 06:53:49,877 INFO Training data converted, got 3132 samples
# 2019-05-07 06:53:49,926 INFO Train set has 3077 phrases, test 165
# 2019-05-07 06:53:53,678 INFO Model: PhraseModel(
#   (emb): Embedding(1950, 50)
#   (encoder): LSTM(50, 512, batch_first=True)
#   (decoder): LSTM(50, 512, batch_first=True)
#   (output): Sequential(
#     (0): Linear(in_features=512, out_features=1950, bias=True)
#   )
# )
# ...

# %% [markdown]
# #### 12:47PM, 11-04-2019

# %%
! git pull
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 2 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/vanvibig/RL-Hands-On-Chatbot
#    868f020..cf2bbd0  add-new-data -> origin/add-new-data
# Updating 868f020..cf2bbd0
# Fast-forward
#  ...t_added_new_data_training_scst_11_04_2019.ipynb | 7731 ++++++++++++++++++++
#  1 file changed, 7731 insertions(+)
#  create mode 100644 RL_Hands_On_Chatbot_added_new_data_training_scst_11_04_2019.ipynb

# %%
# !python use_model.py -m '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data/saves/scstRL/epoch_1690_0.9996738966238987_0.07939356152665039_loss0.0.dat' -f 'sadasd'
# Out:
# Bat dau ghi file
# Ket thuc ghi file
# >>> Traceback (most recent call last):
#   File "use_model.py", line 75, in <module>
# KeyboardInterrupt

# %%
# !zip -r '/content/gdrive/My Drive/Trained_Data/RL-Hands-On-Chatbot-add-new-data_epoch1690_loss_0.001_bleu_0.07.zip' '/content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data/'
# Out:
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data/.git/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data/.git/hooks/ (stored 0%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data/.git/hooks/update.sample (deflated 68%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data/.git/hooks/fsmonitor-watchman.sample (deflated 53%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/gdrive/My Drive/training_code/RL-Hands-On-Chatbot-add-new-data/.git/hooks/pre-push.sample (deflated 50%)
# ...
